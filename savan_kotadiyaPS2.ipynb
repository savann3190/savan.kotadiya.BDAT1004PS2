# %% [markdown]
# # Question 1

# %%
a = 0
def b():
    global a
    a = c(a)
def c(a):
    return a+2

# %%
b()
b()
b()
a
# Out:
# 6

# %% [markdown]
# Explaination:
# Initially the value of a is 0 and defined as a global variable so it can be accessed in other function.
# and then function b and c are defined in which a called as global variable
# in function c we defined a methon so when we call the function the output will be
#
# b() = a+2  |  0+2 = 2  (now a = 2)
# b() = a+2  |  2+2 = 4  (now a = 4)
# b() = a+2  |  4+2 = 6  (now a = 6)
# a = 6

# %% [markdown]
# # Question 2

# %%
import os
def file_length(file_name):
   try: 
    file = open(file_name)
    contents = file.read()
    file.close()
    print(len(contents))
   except FileNotFoundError :
    print("File",str(file_name),"is not found")

# %%
file_length('word.txt')
# Out:
# 5345

# %%
file_length('wor.txt')
# Out:
# File wor.txt is not found

# %% [markdown]
# # Question 3

# %%
class Marsupial:

    def __init__(self):
        self.List = []
   
    def put_in_pouch(self , item):
        self.List.append(item)
  
    def pouch_contents(self):
        return self.List
    
class Kangaroo(Marsupial):
    def __init__(self,x,y):
        Marsupial.__init__(self)
        self.x = x
        self.y = y
    
    def jump(self,dx,dy):
        self.x += dx
        self.y += dy
    def __str__(self):
        return 'I am a Kangaroo located at coordinates ({},{})'.format(self.x,self.y)

# %%
K = Kangaroo(0,0)
print(K)
# Out:
# I am a Kangaroo located at coordinates (0,0)

# %%
K.put_in_pouch('doll')
K.put_in_pouch('firetruck')
K.put_in_pouch('kitten')
print(K.pouch_contents())
# Out:
# ['doll', 'firetruck', 'kitten']

# %%
K.jump(1,0)
K.jump(1,0)
K.jump(1,0)
print(K)
# Out:
# I am a Kangaroo located at coordinates (3,0)

# %% [markdown]
# # Question 4

# %%
def collatz(x):
    print(x)
    
    if x == 1:
        return
    elif x%2 == 0:
        return collatz(int(x/2))
    else:
        return collatz(3*x+1)

# %%
collatz(1)
# Out:
# 1

# %%
collatz(10)
# Out:
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# # Question 5

# %%
def binary(num):
    if(num>0):
        binary(num//2)
        print(num%2,end='')

# %%
binary(0)

# %%
binary(1)
# Out:
# 1

# %%
binary(3)
# Out:
# 11

# %%
binary(9)
# Out:
# 1001

# %% [markdown]
# # Question 6

# %%
from urllib.parse import urljoin
from html.parser import HTMLParser

class HeadinParser(HTMLParser):
    def tags(self , tag , attributes):
        if tag == "h1":
            self.headerFlag = True
            self.indent=0
        elif tag == "h2":
            self.headerFlag = True
            self.indent=1
        elif tag == "h3":
            self.headerFlag = True
            self.indent=2
        elif tag == "h4":
            self.headerFlag = True
            self.indent=3
        elif tag == "h5":
            self.headerFlag = True
            self.indent=4    
        elif tag == "h6":
            self.headerFlag = True
            self.indent=5
        else:
            self.headerFlag = False
            self.indent=0
    def tags2(self , tag , attributes):
        if tag in ["h1" , "h2" , "h3" , "h4" , "h5" , "h6"]:
            self.headerFlag = True

# %%
infile = open('w3c.html')

# %%
words = infile.read()

# %%
infile.close()

# %%
text = HeadinParser()

# %%
text.feed(words)

# %% [markdown]
# # Question 7

# %%
from urllib.request import urlopen
from urllib.parse import urljoin
from html.parser import HTMLParser
def webdir(url):
        print('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html', 2, 0 , url)
        
        content = urlopen(url).read().decode()
        collector = Collector(url)
        collector.feed(content)
        urls = collector.getLinks()
    
        print('\n{:45} {:10}'.format('URL', 'link'))
        for link in urls:
            print('{:45} {:10}'.format(url, link))
        return urls

# %% [markdown]
# # Question 8

# %%
A.
SELECT Temprature() From TABLE;

B.
SELECT DISTINCT(CITY) FROM TABLE;

C.
SELECT*FROM TABLE WHERE COUNTRY = "INDIA";

D.
SELECT*FROM TABLE WHERE SEASON = "FALL";

E.
SELECT CITY,COUNTRY,SEASON FROM TABLE WHERE AVG(RAINFALL(mm)) BETWEEN 200 and 400;

F.
SELET City,Country,Season FROM table WHERE AVG(Temperature) > 20 GROUP BY Season = "Fall";

G.
SELECT SUM(Rainfall(mm)) WHERE City = "Cairo";

H.
SELECT SUM(Rainfall(mm)),Season FROM table GROUP BY(Season);

# %% [markdown]
# # Question 9

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
print([x.upper() for x in words])
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']

# %%
print([x.lower() for x in words])
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
print([len(x) for x in words])
# Out:
# [3, 5, 5, 3, 5, 4, 3, 4, 3]

# %%
print([[x.upper() , x.lower() , len(x)] for x in words])
# Out:
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]

# %%
print([x.lower() for x in words if len(x)>=4])
# Out:
# ['quick', 'brown', 'jumps', 'over', 'lazy']
